# %%
#pip install mediapipe opencv-python

# %%
import cv2
import matplotlib.pyplot as plt
import mediapipe as mp
from IPython.display import Image, display

# %%
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh()

# %%
# Load the input image
image = cv2.imread("C:/Users/ASUS/OneDrive/Pictures/Saved Pictures/3.jpg")
plt.imshow(image)
plt.show()

# %%
# Convert the image to RGB format
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Detect faces in the image
results = face_mesh.process(image_rgb)

# %%
# Draw landmarks on the image
if results.multi_face_landmarks:
    for face_landmarks in results.multi_face_landmarks:
        for landmark in face_landmarks.landmark:
            x = int(landmark.x * image.shape[1])
            y = int(landmark.y * image.shape[0])
            cv2.circle(image, (x, y), radius=2, color=(0, 255, 0), thickness=-1)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display(Image(data=cv2.imencode('.jpg', image_rgb)[1].tobytes()))

# %%
import cv2
import mediapipe as mp
from IPython.display import Image, display


def detect_landmarks(image_path):
    mp_face_mesh = mp.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh()

    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    results = face_mesh.process(image_rgb)

    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            for landmark in face_landmarks.landmark:
                x = int(landmark.x * image.shape[1])
                y = int(landmark.y * image.shape[0])
                cv2.circle(image, (x, y), radius=2, color=(0, 255, 0), thickness=-1)

    # Display the image using IPython.display
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    display(Image(data=cv2.imencode('.jpg', image_rgb)[1].tobytes()))

# %%
# Specify the image path here
image_path = 'C:/Users/ASUS/OneDrive/Pictures/Saved Pictures/1.jpg'

# Perform landmark detection on the specified image path
detect_landmarks(image_path)

# %%
import cv2
import mediapipe as mp
from IPython.display import Image, display

def detect_landmarks(image_path):
    mp_face_mesh = mp.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh()

    # Function to perform landmark detection on the provided image path

    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    results = face_mesh.process(image_rgb)

    pointer_locations = []
    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            for landmark in face_landmarks.landmark:
                x = int(landmark.x * image.shape[1])
                y = int(landmark.y * image.shape[0])
                pointer_locations.append((x, y))
                cv2.circle(image, (x, y), radius=2, color=(0, 255, 0), thickness=-1)

    # Display the image using IPython.display
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    display(Image(data=cv2.imencode('.jpg', image_rgb)[1].tobytes()))

    return pointer_locations

# %%
# Specify the image path here
image_path = 'C:/Users/ASUS/OneDrive/Pictures/Saved Pictures/3.jpg'

# Perform landmark detection on the specified image path
landmark_locations = detect_landmarks(image_path)

# Print the pointer locations
for i, (x, y) in enumerate(landmark_locations):
    print(f"Pointer {i+1}: X={x}, Y={y}")
# Out:
# Pointer 1: X=367, Y=225
# Pointer 2: X=362, Y=200
# Pointer 3: X=364, Y=209
# Pointer 4: X=354, Y=179
# Pointer 5: X=361, Y=193
# Pointer 6: X=360, Y=184
# Pointer 7: X=359, Y=164
# Pointer 8: X=311, Y=174
# Pointer 9: X=357, Y=150
# Pointer 10: X=356, Y=141
# Pointer 11: X=352, Y=112
# Pointer 12: X=368, Y=229
# Pointer 13: X=368, Y=232
# Pointer 14: X=369, Y=233
# Pointer 15: X=369, Y=237
# Pointer 16: X=370, Y=240
# Pointer 17: X=370, Y=244
# Pointer 18: X=371, Y=249
# Pointer 19: X=372, Y=256
# Pointer 20: X=363, Y=204
# Pointer 21: X=357, Y=205
# Pointer 22: X=289, Y=157
# Pointer 23: X=331, Y=176
# Pointer 24: X=325, Y=178
# Pointer 25: X=318, Y=179
# Pointer 26: X=310, Y=177
# Pointer 27: X=337, Y=173
# Pointer 28: X=320, Y=161
# Pointer 29: X=327, Y=160
# Pointer 30: X=313, Y=163
# Pointer 31: X=309, Y=166
# Pointer 32: X=306, Y=182
# Pointer 33: X=347, Y=270
# Pointer 34: X=309, Y=172
# Pointer 35: X=290, Y=185
# Pointer 36: X=299, Y=179
# Pointer 37: X=330, Y=203
# Pointer 38: X=358, Y=226
# Pointer 39: X=361, Y=233
# Pointer 40: X=350, Y=230
# Pointer 41: X=345, Y=234
# Pointer 42: X=355, Y=235
# Pointer 43: X=351, Y=237
# Pointer 44: X=339, Y=248
# Pointer 45: X=356, Y=201
# Pointer 46: X=354, Y=194
# Pointer 47: X=298, Y=161
# Pointer 48: X=341, Y=184
# Pointer 49: X=341, Y=203
# Pointer 50: X=341, Y=200
# Pointer 51: X=311, Y=207
# Pointer 52: X=354, Y=186
# Pointer 53: X=311, Y=150
# Pointer 54: X=303, Y=155
# Pointer 55: X=292, Y=143
# Pointer 56: X=342, Y=151
# Pointer 57: X=334, Y=161
# Pointer 58: X=333, Y=242
# Pointer 59: X=306, Y=247
# Pointer 60: X=347, Y=206
# Pointer 61: X=353, Y=208
# Pointer 62: X=341, Y=241
# Pointer 63: X=344, Y=240
# Pointer 64: X=299, Y=151
# Pointer 65: X=342, Y=207
# Pointer 66: X=324, Y=149
# Pointer 67: X=322, Y=144
# Pointer 68: X=314, Y=122
# Pointer 69: X=296, Y=147
# Pointer 70: X=319, Y=132
# Pointer 71: X=295, Y=159
# Pointer 72: X=292, Y=158
# Pointer 73: X=359, Y=230
# Pointer 74: X=353, Y=233
# Pointer 75: X=348, Y=236
# Pointer 76: X=349, Y=207
# Pointer 77: X=343, Y=241
# Pointer 78: X=345, Y=242
# Pointer 79: X=345, Y=240
# Pointer 80: X=350, Y=203
# Pointer 81: X=352, Y=237
# Pointer 82: X=357, Y=235
# Pointer 83: X=362, Y=234
# Pointer 84: X=363, Y=257
# Pointer 85: X=362, Y=249
# Pointer 86: X=362, Y=245
# Pointer 87: X=362, Y=240
# Pointer 88: X=362, Y=238
# Pointer 89: X=351, Y=239
# Pointer 90: X=350, Y=240
# Pointer 91: X=349, Y=243
# Pointer 92: X=348, Y=246
# Pointer 93: X=339, Y=227
# Pointer 94: X=296, Y=215
# Pointer 95: X=364, Y=206
# Pointer 96: X=348, Y=240
# Pointer 97: X=347, Y=240
# Pointer 98: X=356, Y=210
# Pointer 99: X=345, Y=211
# Pointer 100: X=355, Y=209
# Pointer 101: X=335, Y=189
# Pointer 102: X=325, Y=196
# Pointer 103: X=340, Y=204
# Pointer 104: X=300, Y=132
# Pointer 105: X=304, Y=138
# Pointer 106: X=308, Y=146
# Pointer 107: X=345, Y=252
# Pointer 108: X=338, Y=142
# Pointer 109: X=335, Y=129
# Pointer 110: X=331, Y=116
# Pointer 111: X=313, Y=179
# Pointer 112: X=300, Y=188
# Pointer 113: X=340, Y=170
# Pointer 114: X=303, Y=169
# Pointer 115: X=345, Y=178
# Pointer 116: X=345, Y=200
# Pointer 117: X=295, Y=195
# Pointer 118: X=305, Y=192
# Pointer 119: X=313, Y=193
# Pointer 120: X=325, Y=189
# Pointer 121: X=334, Y=184
# Pointer 122: X=340, Y=180
# Pointer 123: X=352, Y=167
# Pointer 124: X=298, Y=208
# Pointer 125: X=298, Y=170
# Pointer 126: X=360, Y=204
# Pointer 127: X=342, Y=190
# Pointer 128: X=290, Y=186
# Pointer 129: X=345, Y=175
# Pointer 130: X=340, Y=205
# Pointer 131: X=307, Y=173
# Pointer 132: X=344, Y=196
# Pointer 133: X=300, Y=231
# Pointer 134: X=340, Y=168
# Pointer 135: X=349, Y=190
# Pointer 136: X=319, Y=259
# Pointer 137: X=321, Y=268
# Pointer 138: X=294, Y=212
# Pointer 139: X=311, Y=251
# Pointer 140: X=291, Y=171
# Pointer 141: X=347, Y=279
# Pointer 142: X=361, Y=206
# Pointer 143: X=337, Y=196
# Pointer 144: X=294, Y=182
# Pointer 145: X=318, Y=175
# Pointer 146: X=324, Y=174
# Pointer 147: X=344, Y=243
# Pointer 148: X=301, Y=222
# Pointer 149: X=362, Y=287
# Pointer 150: X=340, Y=280
# Pointer 151: X=331, Y=275
# Pointer 152: X=354, Y=126
# Pointer 153: X=378, Y=287
# Pointer 154: X=330, Y=173
# Pointer 155: X=335, Y=170
# Pointer 156: X=338, Y=169
# Pointer 157: X=294, Y=170
# Pointer 158: X=333, Y=164
# Pointer 159: X=327, Y=163
# Pointer 160: X=321, Y=164
# Pointer 161: X=315, Y=166
# Pointer 162: X=312, Y=169
# Pointer 163: X=289, Y=170
# Pointer 164: X=314, Y=174
# Pointer 165: X=365, Y=214
# Pointer 166: X=344, Y=222
# Pointer 167: X=347, Y=205
# Pointer 168: X=356, Y=216
# Pointer 169: X=358, Y=157
# Pointer 170: X=328, Y=267
# Pointer 171: X=337, Y=273
# Pointer 172: X=360, Y=282
# Pointer 173: X=314, Y=259
# Pointer 174: X=338, Y=166
# Pointer 175: X=349, Y=178
# Pointer 176: X=376, Y=281
# Pointer 177: X=349, Y=285
# Pointer 178: X=298, Y=227
# Pointer 179: X=356, Y=238
# Pointer 180: X=355, Y=241
# Pointer 181: X=354, Y=244
# Pointer 182: X=354, Y=248
# Pointer 183: X=353, Y=255
# Pointer 184: X=347, Y=239
# Pointer 185: X=344, Y=239
# Pointer 186: X=342, Y=238
# Pointer 187: X=335, Y=234
# Pointer 188: X=309, Y=223
# Pointer 189: X=349, Y=172
# Pointer 190: X=345, Y=162
# Pointer 191: X=341, Y=164
# Pointer 192: X=349, Y=238
# Pointer 193: X=311, Y=240
# Pointer 194: X=350, Y=160
# Pointer 195: X=350, Y=262
# Pointer 196: X=360, Y=177
# Pointer 197: X=353, Y=174
# Pointer 198: X=359, Y=171
# Pointer 199: X=346, Y=190
# Pointer 200: X=375, Y=273
# Pointer 201: X=373, Y=264
# Pointer 202: X=361, Y=265
# Pointer 203: X=333, Y=252
# Pointer 204: X=336, Y=211
# Pointer 205: X=341, Y=258
# Pointer 206: X=321, Y=213
# Pointer 207: X=331, Y=220
# Pointer 208: X=318, Y=226
# Pointer 209: X=360, Y=274
# Pointer 210: X=343, Y=195
# Pointer 211: X=328, Y=258
# Pointer 212: X=338, Y=265
# Pointer 213: X=327, Y=244
# Pointer 214: X=305, Y=233
# Pointer 215: X=319, Y=246
# Pointer 216: X=303, Y=240
# Pointer 217: X=328, Y=230
# Pointer 218: X=346, Y=184
# Pointer 219: X=347, Y=202
# Pointer 220: X=344, Y=205
# Pointer 221: X=349, Y=197
# Pointer 222: X=338, Y=158
# Pointer 223: X=326, Y=156
# Pointer 224: X=317, Y=157
# Pointer 225: X=309, Y=159
# Pointer 226: X=304, Y=163
# Pointer 227: X=304, Y=176
# Pointer 228: X=291, Y=198
# Pointer 229: X=309, Y=184
# Pointer 230: X=316, Y=185
# Pointer 231: X=325, Y=183
# Pointer 232: X=333, Y=180
# Pointer 233: X=339, Y=176
# Pointer 234: X=343, Y=173
# Pointer 235: X=293, Y=201
# Pointer 236: X=344, Y=207
# Pointer 237: X=349, Y=184
# Pointer 238: X=352, Y=201
# Pointer 239: X=357, Y=204
# Pointer 240: X=352, Y=202
# Pointer 241: X=347, Y=209
# Pointer 242: X=358, Y=204
# Pointer 243: X=359, Y=206
# Pointer 244: X=343, Y=168
# Pointer 245: X=346, Y=168
# Pointer 246: X=348, Y=169
# Pointer 247: X=310, Y=171
# Pointer 248: X=307, Y=169
# Pointer 249: X=366, Y=178
# Pointer 250: X=411, Y=157
# Pointer 251: X=370, Y=203
# Pointer 252: X=432, Y=134
# Pointer 253: X=392, Y=166
# Pointer 254: X=399, Y=165
# Pointer 255: X=406, Y=164
# Pointer 256: X=414, Y=159
# Pointer 257: X=386, Y=165
# Pointer 258: X=398, Y=148
# Pointer 259: X=391, Y=149
# Pointer 260: X=405, Y=147
# Pointer 261: X=411, Y=149
# Pointer 262: X=420, Y=164
# Pointer 263: X=402, Y=262
# Pointer 264: X=413, Y=155
# Pointer 265: X=439, Y=161
# Pointer 266: X=427, Y=159
# Pointer 267: X=399, Y=192
# Pointer 268: X=376, Y=223
# Pointer 269: X=376, Y=231
# Pointer 270: X=385, Y=224
# Pointer 271: X=392, Y=227
# Pointer 272: X=382, Y=230
# Pointer 273: X=388, Y=231
# Pointer 274: X=403, Y=238
# Pointer 275: X=368, Y=199
# Pointer 276: X=368, Y=192
# Pointer 277: X=420, Y=141
# Pointer 278: X=383, Y=177
# Pointer 279: X=386, Y=196
# Pointer 280: X=386, Y=193
# Pointer 281: X=420, Y=190
# Pointer 282: X=367, Y=184
# Pointer 283: X=403, Y=135
# Pointer 284: X=413, Y=136
# Pointer 285: X=424, Y=122
# Pointer 286: X=372, Y=146
# Pointer 287: X=385, Y=152
# Pointer 288: X=407, Y=230
# Pointer 289: X=443, Y=226
# Pointer 290: X=381, Y=201
# Pointer 291: X=375, Y=204
# Pointer 292: X=399, Y=232
# Pointer 293: X=396, Y=232
# Pointer 294: X=416, Y=132
# Pointer 295: X=387, Y=200
# Pointer 296: X=389, Y=138
# Pointer 297: X=390, Y=132
# Pointer 298: X=393, Y=109
# Pointer 299: X=420, Y=126
# Pointer 300: X=390, Y=120
# Pointer 301: X=424, Y=138
# Pointer 302: X=428, Y=136
# Pointer 303: X=376, Y=227
# Pointer 304: X=384, Y=228
# Pointer 305: X=390, Y=229
# Pointer 306: X=380, Y=203
# Pointer 307: X=398, Y=232
# Pointer 308: X=395, Y=234
# Pointer 309: X=395, Y=232
# Pointer 310: X=377, Y=198
# Pointer 311: X=387, Y=231
# Pointer 312: X=381, Y=231
# Pointer 313: X=375, Y=232
# Pointer 314: X=382, Y=254
# Pointer 315: X=380, Y=246
# Pointer 316: X=379, Y=242
# Pointer 317: X=377, Y=238
# Pointer 318: X=376, Y=235
# Pointer 319: X=388, Y=233
# Pointer 320: X=389, Y=234
# Pointer 321: X=392, Y=236
# Pointer 322: X=394, Y=238
# Pointer 323: X=397, Y=218
# Pointer 324: X=445, Y=192
# Pointer 325: X=392, Y=233
# Pointer 326: X=393, Y=233
# Pointer 327: X=373, Y=208
# Pointer 328: X=385, Y=205
# Pointer 329: X=374, Y=206
# Pointer 330: X=391, Y=180
# Pointer 331: X=403, Y=184
# Pointer 332: X=388, Y=196
# Pointer 333: X=411, Y=113
# Pointer 334: X=408, Y=121
# Pointer 335: X=404, Y=130
# Pointer 336: X=398, Y=244
# Pointer 337: X=373, Y=137
# Pointer 338: X=373, Y=123
# Pointer 339: X=374, Y=109
# Pointer 340: X=411, Y=162
# Pointer 341: X=427, Y=168
# Pointer 342: X=381, Y=163
# Pointer 343: X=418, Y=150
# Pointer 344: X=377, Y=173
# Pointer 345: X=381, Y=194
# Pointer 346: X=435, Y=172
# Pointer 347: X=423, Y=173
# Pointer 348: X=415, Y=176
# Pointer 349: X=401, Y=177
# Pointer 350: X=391, Y=175
# Pointer 351: X=383, Y=173
# Pointer 352: X=366, Y=165
# Pointer 353: X=436, Y=186
# Pointer 354: X=424, Y=149
# Pointer 355: X=367, Y=203
# Pointer 356: X=383, Y=184
# Pointer 357: X=441, Y=162
# Pointer 358: X=377, Y=170
# Pointer 359: X=389, Y=197
# Pointer 360: X=416, Y=155
# Pointer 361: X=381, Y=190
# Pointer 362: X=445, Y=208
# Pointer 363: X=381, Y=161
# Pointer 364: X=374, Y=186
# Pointer 365: X=430, Y=242
# Pointer 366: X=432, Y=251
# Pointer 367: X=443, Y=189
# Pointer 368: X=437, Y=232
# Pointer 369: X=433, Y=148
# Pointer 370: X=405, Y=270
# Pointer 371: X=366, Y=205
# Pointer 372: X=390, Y=188
# Pointer 373: X=432, Y=160
# Pointer 374: X=405, Y=160
# Pointer 375: X=399, Y=162
# Pointer 376: X=397, Y=235
# Pointer 377: X=436, Y=200
# Pointer 378: X=393, Y=283
# Pointer 379: X=415, Y=270
# Pointer 380: X=423, Y=262
# Pointer 381: X=393, Y=162
# Pointer 382: X=387, Y=162
# Pointer 383: X=383, Y=161
# Pointer 384: X=428, Y=148
# Pointer 385: X=387, Y=155
# Pointer 386: X=392, Y=153
# Pointer 387: X=398, Y=151
# Pointer 388: X=405, Y=151
# Pointer 389: X=409, Y=153
# Pointer 390: X=437, Y=146
# Pointer 391: X=409, Y=158
# Pointer 392: X=390, Y=214
# Pointer 393: X=381, Y=199
# Pointer 394: X=375, Y=213
# Pointer 395: X=423, Y=253
# Pointer 396: X=415, Y=261
# Pointer 397: X=392, Y=277
# Pointer 398: X=438, Y=240
# Pointer 399: X=383, Y=159
# Pointer 400: X=372, Y=175
# Pointer 401: X=405, Y=277
# Pointer 402: X=443, Y=204
# Pointer 403: X=383, Y=234
# Pointer 404: X=384, Y=236
# Pointer 405: X=386, Y=239
# Pointer 406: X=388, Y=243
# Pointer 407: X=391, Y=249
# Pointer 408: X=393, Y=231
# Pointer 409: X=395, Y=230
# Pointer 410: X=397, Y=229
# Pointer 411: X=403, Y=223
# Pointer 412: X=427, Y=204
# Pointer 413: X=371, Y=169
# Pointer 414: X=374, Y=157
# Pointer 415: X=379, Y=158
# Pointer 416: X=391, Y=231
# Pointer 417: X=431, Y=221
# Pointer 418: X=368, Y=157
# Pointer 419: X=397, Y=255
# Pointer 420: X=366, Y=172
# Pointer 421: X=378, Y=185
# Pointer 422: X=386, Y=261
# Pointer 423: X=411, Y=240
# Pointer 424: X=395, Y=202
# Pointer 425: X=405, Y=248
# Pointer 426: X=411, Y=199
# Pointer 427: X=403, Y=208
# Pointer 428: X=419, Y=210
# Pointer 429: X=390, Y=269
# Pointer 430: X=383, Y=188
# Pointer 431: X=419, Y=245
# Pointer 432: X=411, Y=254
# Pointer 433: X=415, Y=230
# Pointer 434: X=437, Y=212
# Pointer 435: X=424, Y=230
# Pointer 436: X=442, Y=218
# Pointer 437: X=410, Y=217
# Pointer 438: X=377, Y=179
# Pointer 439: X=379, Y=197
# Pointer 440: X=384, Y=199
# Pointer 441: X=375, Y=192
# Pointer 442: X=379, Y=151
# Pointer 443: X=390, Y=145
# Pointer 444: X=400, Y=143
# Pointer 445: X=408, Y=143
# Pointer 446: X=415, Y=145
# Pointer 447: X=420, Y=157
# Pointer 448: X=442, Y=175
# Pointer 449: X=416, Y=167
# Pointer 450: X=409, Y=170
# Pointer 451: X=400, Y=171
# Pointer 452: X=391, Y=170
# Pointer 453: X=384, Y=169
# Pointer 454: X=379, Y=167
# Pointer 455: X=443, Y=177
# Pointer 456: X=384, Y=201
# Pointer 457: X=372, Y=180
# Pointer 458: X=373, Y=197
# Pointer 459: X=370, Y=202
# Pointer 460: X=374, Y=199
# Pointer 461: X=382, Y=204
# Pointer 462: X=369, Y=202
# Pointer 463: X=369, Y=204
# Pointer 464: X=379, Y=162
# Pointer 465: X=374, Y=164
# Pointer 466: X=372, Y=165
# Pointer 467: X=411, Y=154
# Pointer 468: X=415, Y=151

# %%
import cv2
import mediapipe as mp
from IPython.display import Image, display

def detect_landmarks(image_path):
    mp_face_mesh = mp.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh()

    # Function to perform landmark detection on the provided image path
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    results = face_mesh.process(image_rgb)

    pointer_locations = []
    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            for i, landmark in enumerate(face_landmarks.landmark):
                x = int(landmark.x * image.shape[1])
                y = int(landmark.y * image.shape[0])
                pointer_locations.append((x, y))
                cv2.circle(image, (x, y), radius=2, color=(0, 0, 0), thickness=-1)
                cv2.putText(image, f"{i+1}", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.25, (0, 0, 0), 1, cv2.LINE_AA)

    # Display the image using IPython.display
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    display(Image(data=cv2.imencode('.jpg', image_rgb)[1].tobytes()))

    return pointer_locations

# %%
# Specify the image path here
image_path = 'C:/Users/ASUS/OneDrive/Pictures/Saved Pictures/2.jpg'

# Perform landmark detection on the specified image path
landmark_locations = detect_landmarks(image_path)

# Print the pointer locations
for i, (x, y) in enumerate(landmark_locations):
    print(f"Pointer {i+1}: X={x}, Y={y}")
# Out:
# Pointer 1: X=192, Y=587
# Pointer 2: X=159, Y=533
# Pointer 3: X=184, Y=549
# Pointer 4: X=150, Y=485
# Pointer 5: X=153, Y=517
# Pointer 6: X=155, Y=496
# Pointer 7: X=166, Y=445
# Pointer 8: X=100, Y=470
# Pointer 9: X=161, Y=404
# Pointer 10: X=154, Y=383
# Pointer 11: X=141, Y=302
# Pointer 12: X=195, Y=595
# Pointer 13: X=200, Y=602
# Pointer 14: X=206, Y=605
# Pointer 15: X=209, Y=616
# Pointer 16: X=209, Y=625
# Pointer 17: X=211, Y=634
# Pointer 18: X=216, Y=645
# Pointer 19: X=228, Y=658
# Pointer 20: X=167, Y=542
# Pointer 21: X=165, Y=544
# Pointer 22: X=78, Y=421
# Pointer 23: X=138, Y=471
# Pointer 24: X=125, Y=477
# Pointer 25: X=113, Y=480
# Pointer 26: X=101, Y=476
# Pointer 27: X=147, Y=463
# Pointer 28: X=107, Y=436
# Pointer 29: X=121, Y=432
# Pointer 30: X=95, Y=442
# Pointer 31: X=91, Y=450
# Pointer 32: X=96, Y=489
# Pointer 33: X=196, Y=689
# Pointer 34: X=97, Y=467
# Pointer 35: X=96, Y=487
# Pointer 36: X=90, Y=481
# Pointer 37: X=130, Y=540
# Pointer 38: X=176, Y=588
# Pointer 39: X=189, Y=605
# Pointer 40: X=166, Y=597
# Pointer 41: X=164, Y=607
# Pointer 42: X=181, Y=608
# Pointer 43: X=177, Y=613
# Pointer 44: X=169, Y=639
# Pointer 45: X=149, Y=536
# Pointer 46: X=143, Y=521
# Pointer 47: X=74, Y=442
# Pointer 48: X=148, Y=492
# Pointer 49: X=140, Y=540
# Pointer 50: X=140, Y=532
# Pointer 51: X=102, Y=551
# Pointer 52: X=145, Y=502
# Pointer 53: X=85, Y=418
# Pointer 54: X=75, Y=428
# Pointer 55: X=69, Y=391
# Pointer 56: X=135, Y=412
# Pointer 57: X=135, Y=434
# Pointer 58: X=156, Y=625
# Pointer 59: X=165, Y=627
# Pointer 60: X=153, Y=546
# Pointer 61: X=164, Y=548
# Pointer 62: X=167, Y=621
# Pointer 63: X=174, Y=618
# Pointer 64: X=70, Y=420
# Pointer 65: X=147, Y=547
# Pointer 66: X=104, Y=412
# Pointer 67: X=97, Y=400
# Pointer 68: X=81, Y=339
# Pointer 69: X=69, Y=405
# Pointer 70: X=88, Y=368
# Pointer 71: X=71, Y=437
# Pointer 72: X=74, Y=430
# Pointer 73: X=181, Y=598
# Pointer 74: X=173, Y=604
# Pointer 75: X=170, Y=610
# Pointer 76: X=159, Y=548
# Pointer 77: X=170, Y=620
# Pointer 78: X=174, Y=624
# Pointer 79: X=177, Y=617
# Pointer 80: X=148, Y=539
# Pointer 81: X=183, Y=611
# Pointer 82: X=188, Y=609
# Pointer 83: X=196, Y=607
# Pointer 84: X=210, Y=661
# Pointer 85: X=199, Y=646
# Pointer 86: X=195, Y=636
# Pointer 87: X=195, Y=626
# Pointer 88: X=197, Y=619
# Pointer 89: X=183, Y=620
# Pointer 90: X=180, Y=623
# Pointer 91: X=177, Y=629
# Pointer 92: X=177, Y=635
# Pointer 93: X=151, Y=593
# Pointer 94: X=139, Y=552
# Pointer 95: X=175, Y=545
# Pointer 96: X=181, Y=619
# Pointer 97: X=177, Y=621
# Pointer 98: X=170, Y=554
# Pointer 99: X=157, Y=555
# Pointer 100: X=167, Y=551
# Pointer 101: X=138, Y=505
# Pointer 102: X=121, Y=523
# Pointer 103: X=144, Y=539
# Pointer 104: X=69, Y=364
# Pointer 105: X=73, Y=384
# Pointer 106: X=79, Y=407
# Pointer 107: X=180, Y=649
# Pointer 108: X=123, Y=393
# Pointer 109: X=112, Y=356
# Pointer 110: X=104, Y=320
# Pointer 111: X=105, Y=480
# Pointer 112: X=91, Y=504
# Pointer 113: X=152, Y=456
# Pointer 114: X=87, Y=460
# Pointer 115: X=152, Y=479
# Pointer 116: X=138, Y=532
# Pointer 117: X=89, Y=518
# Pointer 118: X=93, Y=514
# Pointer 119: X=103, Y=515
# Pointer 120: X=123, Y=505
# Pointer 121: X=139, Y=492
# Pointer 122: X=149, Y=480
# Pointer 123: X=157, Y=453
# Pointer 124: X=93, Y=551
# Pointer 125: X=82, Y=460
# Pointer 126: X=161, Y=543
# Pointer 127: X=148, Y=507
# Pointer 128: X=113, Y=485
# Pointer 129: X=155, Y=468
# Pointer 130: X=149, Y=540
# Pointer 131: X=95, Y=468
# Pointer 132: X=140, Y=522
# Pointer 133: X=151, Y=589
# Pointer 134: X=152, Y=450
# Pointer 135: X=141, Y=510
# Pointer 136: X=163, Y=662
# Pointer 137: X=184, Y=677
# Pointer 138: X=109, Y=555
# Pointer 139: X=150, Y=645
# Pointer 140: X=84, Y=457
# Pointer 141: X=202, Y=705
# Pointer 142: X=170, Y=546
# Pointer 143: X=143, Y=522
# Pointer 144: X=89, Y=486
# Pointer 145: X=111, Y=471
# Pointer 146: X=122, Y=469
# Pointer 147: X=172, Y=628
# Pointer 148: X=105, Y=582
# Pointer 149: X=232, Y=722
# Pointer 150: X=205, Y=705
# Pointer 151: X=196, Y=694
# Pointer 152: X=146, Y=342
# Pointer 153: X=260, Y=721
# Pointer 154: X=133, Y=464
# Pointer 155: X=143, Y=458
# Pointer 156: X=149, Y=453
# Pointer 157: X=80, Y=459
# Pointer 158: X=139, Y=445
# Pointer 159: X=128, Y=445
# Pointer 160: X=115, Y=448
# Pointer 161: X=105, Y=454
# Pointer 162: X=100, Y=460
# Pointer 163: X=93, Y=450
# Pointer 164: X=104, Y=471
# Pointer 165: X=188, Y=561
# Pointer 166: X=156, Y=580
# Pointer 167: X=149, Y=543
# Pointer 168: X=171, Y=568
# Pointer 169: X=168, Y=424
# Pointer 170: X=178, Y=678
# Pointer 171: X=190, Y=691
# Pointer 172: X=220, Y=713
# Pointer 173: X=176, Y=657
# Pointer 174: X=148, Y=448
# Pointer 175: X=150, Y=481
# Pointer 176: X=248, Y=711
# Pointer 177: X=215, Y=715
# Pointer 178: X=122, Y=588
# Pointer 179: X=188, Y=619
# Pointer 180: X=186, Y=625
# Pointer 181: X=184, Y=633
# Pointer 182: X=186, Y=643
# Pointer 183: X=193, Y=657
# Pointer 184: X=175, Y=615
# Pointer 185: X=169, Y=615
# Pointer 186: X=164, Y=614
# Pointer 187: X=151, Y=608
# Pointer 188: X=110, Y=587
# Pointer 189: X=155, Y=465
# Pointer 190: X=153, Y=436
# Pointer 191: X=150, Y=440
# Pointer 192: X=180, Y=613
# Pointer 193: X=132, Y=623
# Pointer 194: X=156, Y=432
# Pointer 195: X=195, Y=672
# Pointer 196: X=159, Y=479
# Pointer 197: X=153, Y=470
# Pointer 198: X=163, Y=463
# Pointer 199: X=146, Y=508
# Pointer 200: X=239, Y=696
# Pointer 201: X=233, Y=676
# Pointer 202: X=212, Y=678
# Pointer 203: X=166, Y=648
# Pointer 204: X=144, Y=557
# Pointer 205: X=180, Y=662
# Pointer 206: X=118, Y=566
# Pointer 207: X=138, Y=578
# Pointer 208: X=122, Y=594
# Pointer 209: X=214, Y=698
# Pointer 210: X=147, Y=519
# Pointer 211: X=166, Y=662
# Pointer 212: X=182, Y=676
# Pointer 213: X=150, Y=630
# Pointer 214: X=121, Y=607
# Pointer 215: X=144, Y=637
# Pointer 216: X=137, Y=618
# Pointer 217: X=138, Y=601
# Pointer 218: X=150, Y=494
# Pointer 219: X=143, Y=538
# Pointer 220: X=144, Y=544
# Pointer 221: X=139, Y=526
# Pointer 222: X=138, Y=426
# Pointer 223: X=114, Y=424
# Pointer 224: X=97, Y=429
# Pointer 225: X=85, Y=437
# Pointer 226: X=82, Y=447
# Pointer 227: X=93, Y=474
# Pointer 228: X=101, Y=521
# Pointer 229: X=100, Y=494
# Pointer 230: X=109, Y=495
# Pointer 231: X=124, Y=490
# Pointer 232: X=139, Y=481
# Pointer 233: X=150, Y=471
# Pointer 234: X=155, Y=463
# Pointer 235: X=129, Y=518
# Pointer 236: X=150, Y=548
# Pointer 237: X=146, Y=495
# Pointer 238: X=144, Y=536
# Pointer 239: X=159, Y=542
# Pointer 240: X=150, Y=538
# Pointer 241: X=157, Y=551
# Pointer 242: X=159, Y=543
# Pointer 243: X=167, Y=546
# Pointer 244: X=155, Y=449
# Pointer 245: X=159, Y=452
# Pointer 246: X=158, Y=453
# Pointer 247: X=98, Y=464
# Pointer 248: X=91, Y=459
# Pointer 249: X=174, Y=477
# Pointer 250: X=308, Y=397
# Pointer 251: X=190, Y=538
# Pointer 252: X=393, Y=304
# Pointer 253: X=261, Y=429
# Pointer 254: X=278, Y=425
# Pointer 255: X=295, Y=419
# Pointer 256: X=320, Y=400
# Pointer 257: X=246, Y=429
# Pointer 258: X=264, Y=373
# Pointer 259: X=247, Y=382
# Pointer 260: X=284, Y=369
# Pointer 261: X=301, Y=371
# Pointer 262: X=339, Y=407
# Pointer 263: X=307, Y=666
# Pointer 264: X=315, Y=390
# Pointer 265: X=420, Y=378
# Pointer 266: X=362, Y=388
# Pointer 267: X=278, Y=496
# Pointer 268: X=212, Y=580
# Pointer 269: X=220, Y=598
# Pointer 270: X=241, Y=580
# Pointer 271: X=264, Y=583
# Pointer 272: X=240, Y=595
# Pointer 273: X=259, Y=594
# Pointer 274: X=308, Y=605
# Pointer 275: X=172, Y=530
# Pointer 276: X=170, Y=513
# Pointer 277: X=324, Y=346
# Pointer 278: X=236, Y=464
# Pointer 279: X=230, Y=515
# Pointer 280: X=233, Y=505
# Pointer 281: X=341, Y=478
# Pointer 282: X=171, Y=494
# Pointer 283: X=262, Y=344
# Pointer 284: X=294, Y=340
# Pointer 285: X=349, Y=282
# Pointer 286: X=193, Y=387
# Pointer 287: X=235, Y=394
# Pointer 288: X=316, Y=585
# Pointer 289: X=474, Y=544
# Pointer 290: X=221, Y=528
# Pointer 291: X=208, Y=537
# Pointer 292: X=296, Y=590
# Pointer 293: X=289, Y=591
# Pointer 294: X=303, Y=325
# Pointer 295: X=238, Y=522
# Pointer 296: X=228, Y=359
# Pointer 297: X=226, Y=344
# Pointer 298: X=240, Y=273
# Pointer 299: X=324, Y=304
# Pointer 300: X=228, Y=309
# Pointer 301: X=338, Y=335
# Pointer 302: X=364, Y=321
# Pointer 303: X=216, Y=590
# Pointer 304: X=240, Y=589
# Pointer 305: X=261, Y=589
# Pointer 306: X=219, Y=532
# Pointer 307: X=292, Y=591
# Pointer 308: X=283, Y=598
# Pointer 309: X=288, Y=590
# Pointer 310: X=202, Y=525
# Pointer 311: X=259, Y=593
# Pointer 312: X=242, Y=596
# Pointer 313: X=223, Y=600
# Pointer 314: X=252, Y=651
# Pointer 315: X=238, Y=637
# Pointer 316: X=232, Y=627
# Pointer 317: X=229, Y=618
# Pointer 318: X=227, Y=612
# Pointer 319: X=263, Y=601
# Pointer 320: X=266, Y=602
# Pointer 321: X=270, Y=606
# Pointer 322: X=276, Y=611
# Pointer 323: X=276, Y=560
# Pointer 324: X=473, Y=449
# Pointer 325: X=276, Y=596
# Pointer 326: X=278, Y=597
# Pointer 327: X=205, Y=546
# Pointer 328: X=238, Y=534
# Pointer 329: X=206, Y=542
# Pointer 330: X=258, Y=468
# Pointer 331: X=289, Y=471
# Pointer 332: X=242, Y=512
# Pointer 333: X=299, Y=271
# Pointer 334: X=280, Y=299
# Pointer 335: X=265, Y=329
# Pointer 336: X=294, Y=622
# Pointer 337: X=188, Y=364
# Pointer 338: X=186, Y=324
# Pointer 339: X=189, Y=284
# Pointer 340: X=311, Y=410
# Pointer 341: X=365, Y=414
# Pointer 342: X=235, Y=427
# Pointer 343: X=328, Y=372
# Pointer 344: X=219, Y=457
# Pointer 345: X=211, Y=512
# Pointer 346: X=396, Y=418
# Pointer 347: X=350, Y=431
# Pointer 348: X=322, Y=445
# Pointer 349: X=285, Y=453
# Pointer 350: X=259, Y=453
# Pointer 351: X=238, Y=451
# Pointer 352: X=183, Y=444
# Pointer 353: X=402, Y=456
# Pointer 354: X=344, Y=365
# Pointer 355: X=175, Y=539
# Pointer 356: X=233, Y=481
# Pointer 357: X=450, Y=370
# Pointer 358: X=221, Y=446
# Pointer 359: X=250, Y=512
# Pointer 360: X=324, Y=387
# Pointer 361: X=214, Y=500
# Pointer 362: X=479, Y=494
# Pointer 363: X=235, Y=421
# Pointer 364: X=191, Y=495
# Pointer 365: X=404, Y=605
# Pointer 366: X=424, Y=623
# Pointer 367: X=445, Y=451
# Pointer 368: X=431, Y=573
# Pointer 369: X=394, Y=346
# Pointer 370: X=318, Y=682
# Pointer 371: X=181, Y=543
# Pointer 372: X=254, Y=488
# Pointer 373: X=385, Y=386
# Pointer 374: X=289, Y=410
# Pointer 375: X=274, Y=416
# Pointer 376: X=289, Y=600
# Pointer 377: X=411, Y=492
# Pointer 378: X=294, Y=711
# Pointer 379: X=358, Y=676
# Pointer 380: X=388, Y=654
# Pointer 381: X=260, Y=419
# Pointer 382: X=248, Y=420
# Pointer 383: X=240, Y=421
# Pointer 384: X=364, Y=357
# Pointer 385: X=245, Y=406
# Pointer 386: X=256, Y=397
# Pointer 387: X=270, Y=391
# Pointer 388: X=286, Y=388
# Pointer 389: X=298, Y=388
# Pointer 390: X=424, Y=332
# Pointer 391: X=300, Y=403
# Pointer 392: X=253, Y=555
# Pointer 393: X=218, Y=525
# Pointer 394: X=211, Y=558
# Pointer 395: X=376, Y=635
# Pointer 396: X=349, Y=659
# Pointer 397: X=284, Y=701
# Pointer 398: X=454, Y=588
# Pointer 399: X=237, Y=416
# Pointer 400: X=197, Y=466
# Pointer 401: X=326, Y=695
# Pointer 402: X=452, Y=492
# Pointer 403: X=246, Y=606
# Pointer 404: X=249, Y=610
# Pointer 405: X=253, Y=616
# Pointer 406: X=258, Y=625
# Pointer 407: X=275, Y=638
# Pointer 408: X=277, Y=591
# Pointer 409: X=280, Y=589
# Pointer 410: X=284, Y=585
# Pointer 411: X=298, Y=570
# Pointer 412: X=375, Y=511
# Pointer 413: X=200, Y=449
# Pointer 414: X=213, Y=413
# Pointer 415: X=227, Y=412
# Pointer 416: X=275, Y=590
# Pointer 417: X=400, Y=552
# Pointer 418: X=191, Y=418
# Pointer 419: X=293, Y=651
# Pointer 420: X=179, Y=462
# Pointer 421: X=214, Y=487
# Pointer 422: X=263, Y=667
# Pointer 423: X=330, Y=608
# Pointer 424: X=270, Y=522
# Pointer 425: X=315, Y=632
# Pointer 426: X=314, Y=508
# Pointer 427: X=292, Y=534
# Pointer 428: X=343, Y=532
# Pointer 429: X=274, Y=686
# Pointer 430: X=232, Y=493
# Pointer 431: X=355, Y=618
# Pointer 432: X=333, Y=643
# Pointer 433: X=338, Y=583
# Pointer 434: X=419, Y=524
# Pointer 435: X=371, Y=579
# Pointer 436: X=451, Y=532
# Pointer 437: X=316, Y=553
# Pointer 438: X=215, Y=473
# Pointer 439: X=205, Y=521
# Pointer 440: X=225, Y=522
# Pointer 441: X=189, Y=512
# Pointer 442: X=218, Y=394
# Pointer 443: X=239, Y=374
# Pointer 444: X=262, Y=362
# Pointer 445: X=286, Y=358
# Pointer 446: X=309, Y=360
# Pointer 447: X=340, Y=388
# Pointer 448: X=434, Y=413
# Pointer 449: X=328, Y=418
# Pointer 450: X=308, Y=430
# Pointer 451: X=283, Y=437
# Pointer 452: X=260, Y=440
# Pointer 453: X=242, Y=439
# Pointer 454: X=229, Y=437
# Pointer 455: X=464, Y=409
# Pointer 456: X=229, Y=526
# Pointer 457: X=193, Y=481
# Pointer 458: X=187, Y=525
# Pointer 459: X=185, Y=535
# Pointer 460: X=192, Y=528
# Pointer 461: X=229, Y=533
# Pointer 462: X=181, Y=537
# Pointer 463: X=186, Y=541
# Pointer 464: X=227, Y=423
# Pointer 465: X=216, Y=431
# Pointer 466: X=207, Y=436
# Pointer 467: X=307, Y=389
# Pointer 468: X=316, Y=376

# %%
import cv2
import mediapipe as mp
from IPython.display import Image, display

def detect_landmarks(image_path):
    mp_face_mesh = mp.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh()

    # Function to perform landmark detection on the provided image path
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    results = face_mesh.process(image_rgb)

    pointer_locations = []
    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            for i, landmark in enumerate(face_landmarks.landmark):
                x = int(landmark.x * image.shape[1])
                y = int(landmark.y * image.shape[0])
                pointer_locations.append((x, y))
                cv2.circle(image, (x, y), radius=2, color=(0, 0, 0), thickness=-1)
                cv2.putText(image, f"({x}, {y})",  (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.15, (0, 0, 0), 1, cv2.LINE_AA)

    # Display the image using IPython.display
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    display(Image(data=cv2.imencode('.jpg', image_rgb)[1].tobytes()))

    return pointer_locations

# %%
# Specify the image path here
image_path = 'C:/Users/ASUS/OneDrive/Pictures/Saved Pictures/2.jpg'

# Perform landmark detection on the specified image path
landmark_locations = detect_landmarks(image_path)

# Print the pointer locations
for i, (x, y) in enumerate(landmark_locations):
    print(f"Pointer {i+1}: X={x}, Y={y}")
# Out:
# Pointer 1: X=192, Y=587
# Pointer 2: X=159, Y=533
# Pointer 3: X=184, Y=549
# Pointer 4: X=150, Y=485
# Pointer 5: X=153, Y=517
# Pointer 6: X=155, Y=496
# Pointer 7: X=166, Y=445
# Pointer 8: X=100, Y=470
# Pointer 9: X=161, Y=404
# Pointer 10: X=154, Y=383
# Pointer 11: X=141, Y=302
# Pointer 12: X=195, Y=595
# Pointer 13: X=200, Y=602
# Pointer 14: X=206, Y=605
# Pointer 15: X=209, Y=616
# Pointer 16: X=209, Y=625
# Pointer 17: X=211, Y=634
# Pointer 18: X=216, Y=645
# Pointer 19: X=228, Y=658
# Pointer 20: X=167, Y=542
# Pointer 21: X=165, Y=544
# Pointer 22: X=78, Y=421
# Pointer 23: X=138, Y=471
# Pointer 24: X=125, Y=477
# Pointer 25: X=113, Y=480
# Pointer 26: X=101, Y=476
# Pointer 27: X=147, Y=463
# Pointer 28: X=107, Y=436
# Pointer 29: X=121, Y=432
# Pointer 30: X=95, Y=442
# Pointer 31: X=91, Y=450
# Pointer 32: X=96, Y=489
# Pointer 33: X=196, Y=689
# Pointer 34: X=97, Y=467
# Pointer 35: X=96, Y=487
# Pointer 36: X=90, Y=481
# Pointer 37: X=130, Y=540
# Pointer 38: X=176, Y=588
# Pointer 39: X=189, Y=605
# Pointer 40: X=166, Y=597
# Pointer 41: X=164, Y=607
# Pointer 42: X=181, Y=608
# Pointer 43: X=177, Y=613
# Pointer 44: X=169, Y=639
# Pointer 45: X=149, Y=536
# Pointer 46: X=143, Y=521
# Pointer 47: X=74, Y=442
# Pointer 48: X=148, Y=492
# Pointer 49: X=140, Y=540
# Pointer 50: X=140, Y=532
# Pointer 51: X=102, Y=551
# Pointer 52: X=145, Y=502
# Pointer 53: X=85, Y=418
# Pointer 54: X=75, Y=428
# Pointer 55: X=69, Y=391
# Pointer 56: X=135, Y=412
# Pointer 57: X=135, Y=434
# Pointer 58: X=156, Y=625
# Pointer 59: X=165, Y=627
# Pointer 60: X=153, Y=546
# Pointer 61: X=164, Y=548
# Pointer 62: X=167, Y=621
# Pointer 63: X=174, Y=618
# Pointer 64: X=70, Y=420
# Pointer 65: X=147, Y=547
# Pointer 66: X=104, Y=412
# Pointer 67: X=97, Y=400
# Pointer 68: X=81, Y=339
# Pointer 69: X=69, Y=405
# Pointer 70: X=88, Y=368
# Pointer 71: X=71, Y=437
# Pointer 72: X=74, Y=430
# Pointer 73: X=181, Y=598
# Pointer 74: X=173, Y=604
# Pointer 75: X=170, Y=610
# Pointer 76: X=159, Y=548
# Pointer 77: X=170, Y=620
# Pointer 78: X=174, Y=624
# Pointer 79: X=177, Y=617
# Pointer 80: X=148, Y=539
# Pointer 81: X=183, Y=611
# Pointer 82: X=188, Y=609
# Pointer 83: X=196, Y=607
# Pointer 84: X=210, Y=661
# Pointer 85: X=199, Y=646
# Pointer 86: X=195, Y=636
# Pointer 87: X=195, Y=626
# Pointer 88: X=197, Y=619
# Pointer 89: X=183, Y=620
# Pointer 90: X=180, Y=623
# Pointer 91: X=177, Y=629
# Pointer 92: X=177, Y=635
# Pointer 93: X=151, Y=593
# Pointer 94: X=139, Y=552
# Pointer 95: X=175, Y=545
# Pointer 96: X=181, Y=619
# Pointer 97: X=177, Y=621
# Pointer 98: X=170, Y=554
# Pointer 99: X=157, Y=555
# Pointer 100: X=167, Y=551
# Pointer 101: X=138, Y=505
# Pointer 102: X=121, Y=523
# Pointer 103: X=144, Y=539
# Pointer 104: X=69, Y=364
# Pointer 105: X=73, Y=384
# Pointer 106: X=79, Y=407
# Pointer 107: X=180, Y=649
# Pointer 108: X=123, Y=393
# Pointer 109: X=112, Y=356
# Pointer 110: X=104, Y=320
# Pointer 111: X=105, Y=480
# Pointer 112: X=91, Y=504
# Pointer 113: X=152, Y=456
# Pointer 114: X=87, Y=460
# Pointer 115: X=152, Y=479
# Pointer 116: X=138, Y=532
# Pointer 117: X=89, Y=518
# Pointer 118: X=93, Y=514
# Pointer 119: X=103, Y=515
# Pointer 120: X=123, Y=505
# Pointer 121: X=139, Y=492
# Pointer 122: X=149, Y=480
# Pointer 123: X=157, Y=453
# Pointer 124: X=93, Y=551
# Pointer 125: X=82, Y=460
# Pointer 126: X=161, Y=543
# Pointer 127: X=148, Y=507
# Pointer 128: X=113, Y=485
# Pointer 129: X=155, Y=468
# Pointer 130: X=149, Y=540
# Pointer 131: X=95, Y=468
# Pointer 132: X=140, Y=522
# Pointer 133: X=151, Y=589
# Pointer 134: X=152, Y=450
# Pointer 135: X=141, Y=510
# Pointer 136: X=163, Y=662
# Pointer 137: X=184, Y=677
# Pointer 138: X=109, Y=555
# Pointer 139: X=150, Y=645
# Pointer 140: X=84, Y=457
# Pointer 141: X=202, Y=705
# Pointer 142: X=170, Y=546
# Pointer 143: X=143, Y=522
# Pointer 144: X=89, Y=486
# Pointer 145: X=111, Y=471
# Pointer 146: X=122, Y=469
# Pointer 147: X=172, Y=628
# Pointer 148: X=105, Y=582
# Pointer 149: X=232, Y=722
# Pointer 150: X=205, Y=705
# Pointer 151: X=196, Y=694
# Pointer 152: X=146, Y=342
# Pointer 153: X=260, Y=721
# Pointer 154: X=133, Y=464
# Pointer 155: X=143, Y=458
# Pointer 156: X=149, Y=453
# Pointer 157: X=80, Y=459
# Pointer 158: X=139, Y=445
# Pointer 159: X=128, Y=445
# Pointer 160: X=115, Y=448
# Pointer 161: X=105, Y=454
# Pointer 162: X=100, Y=460
# Pointer 163: X=93, Y=450
# Pointer 164: X=104, Y=471
# Pointer 165: X=188, Y=561
# Pointer 166: X=156, Y=580
# Pointer 167: X=149, Y=543
# Pointer 168: X=171, Y=568
# Pointer 169: X=168, Y=424
# Pointer 170: X=178, Y=678
# Pointer 171: X=190, Y=691
# Pointer 172: X=220, Y=713
# Pointer 173: X=176, Y=657
# Pointer 174: X=148, Y=448
# Pointer 175: X=150, Y=481
# Pointer 176: X=248, Y=711
# Pointer 177: X=215, Y=715
# Pointer 178: X=122, Y=588
# Pointer 179: X=188, Y=619
# Pointer 180: X=186, Y=625
# Pointer 181: X=184, Y=633
# Pointer 182: X=186, Y=643
# Pointer 183: X=193, Y=657
# Pointer 184: X=175, Y=615
# Pointer 185: X=169, Y=615
# Pointer 186: X=164, Y=614
# Pointer 187: X=151, Y=608
# Pointer 188: X=110, Y=587
# Pointer 189: X=155, Y=465
# Pointer 190: X=153, Y=436
# Pointer 191: X=150, Y=440
# Pointer 192: X=180, Y=613
# Pointer 193: X=132, Y=623
# Pointer 194: X=156, Y=432
# Pointer 195: X=195, Y=672
# Pointer 196: X=159, Y=479
# Pointer 197: X=153, Y=470
# Pointer 198: X=163, Y=463
# Pointer 199: X=146, Y=508
# Pointer 200: X=239, Y=696
# Pointer 201: X=233, Y=676
# Pointer 202: X=212, Y=678
# Pointer 203: X=166, Y=648
# Pointer 204: X=144, Y=557
# Pointer 205: X=180, Y=662
# Pointer 206: X=118, Y=566
# Pointer 207: X=138, Y=578
# Pointer 208: X=122, Y=594
# Pointer 209: X=214, Y=698
# Pointer 210: X=147, Y=519
# Pointer 211: X=166, Y=662
# Pointer 212: X=182, Y=676
# Pointer 213: X=150, Y=630
# Pointer 214: X=121, Y=607
# Pointer 215: X=144, Y=637
# Pointer 216: X=137, Y=618
# Pointer 217: X=138, Y=601
# Pointer 218: X=150, Y=494
# Pointer 219: X=143, Y=538
# Pointer 220: X=144, Y=544
# Pointer 221: X=139, Y=526
# Pointer 222: X=138, Y=426
# Pointer 223: X=114, Y=424
# Pointer 224: X=97, Y=429
# Pointer 225: X=85, Y=437
# Pointer 226: X=82, Y=447
# Pointer 227: X=93, Y=474
# Pointer 228: X=101, Y=521
# Pointer 229: X=100, Y=494
# Pointer 230: X=109, Y=495
# Pointer 231: X=124, Y=490
# Pointer 232: X=139, Y=481
# Pointer 233: X=150, Y=471
# Pointer 234: X=155, Y=463
# Pointer 235: X=129, Y=518
# Pointer 236: X=150, Y=548
# Pointer 237: X=146, Y=495
# Pointer 238: X=144, Y=536
# Pointer 239: X=159, Y=542
# Pointer 240: X=150, Y=538
# Pointer 241: X=157, Y=551
# Pointer 242: X=159, Y=543
# Pointer 243: X=167, Y=546
# Pointer 244: X=155, Y=449
# Pointer 245: X=159, Y=452
# Pointer 246: X=158, Y=453
# Pointer 247: X=98, Y=464
# Pointer 248: X=91, Y=459
# Pointer 249: X=174, Y=477
# Pointer 250: X=308, Y=397
# Pointer 251: X=190, Y=538
# Pointer 252: X=393, Y=304
# Pointer 253: X=261, Y=429
# Pointer 254: X=278, Y=425
# Pointer 255: X=295, Y=419
# Pointer 256: X=320, Y=400
# Pointer 257: X=246, Y=429
# Pointer 258: X=264, Y=373
# Pointer 259: X=247, Y=382
# Pointer 260: X=284, Y=369
# Pointer 261: X=301, Y=371
# Pointer 262: X=339, Y=407
# Pointer 263: X=307, Y=666
# Pointer 264: X=315, Y=390
# Pointer 265: X=420, Y=378
# Pointer 266: X=362, Y=388
# Pointer 267: X=278, Y=496
# Pointer 268: X=212, Y=580
# Pointer 269: X=220, Y=598
# Pointer 270: X=241, Y=580
# Pointer 271: X=264, Y=583
# Pointer 272: X=240, Y=595
# Pointer 273: X=259, Y=594
# Pointer 274: X=308, Y=605
# Pointer 275: X=172, Y=530
# Pointer 276: X=170, Y=513
# Pointer 277: X=324, Y=346
# Pointer 278: X=236, Y=464
# Pointer 279: X=230, Y=515
# Pointer 280: X=233, Y=505
# Pointer 281: X=341, Y=478
# Pointer 282: X=171, Y=494
# Pointer 283: X=262, Y=344
# Pointer 284: X=294, Y=340
# Pointer 285: X=349, Y=282
# Pointer 286: X=193, Y=387
# Pointer 287: X=235, Y=394
# Pointer 288: X=316, Y=585
# Pointer 289: X=474, Y=544
# Pointer 290: X=221, Y=528
# Pointer 291: X=208, Y=537
# Pointer 292: X=296, Y=590
# Pointer 293: X=289, Y=591
# Pointer 294: X=303, Y=325
# Pointer 295: X=238, Y=522
# Pointer 296: X=228, Y=359
# Pointer 297: X=226, Y=344
# Pointer 298: X=240, Y=273
# Pointer 299: X=324, Y=304
# Pointer 300: X=228, Y=309
# Pointer 301: X=338, Y=335
# Pointer 302: X=364, Y=321
# Pointer 303: X=216, Y=590
# Pointer 304: X=240, Y=589
# Pointer 305: X=261, Y=589
# Pointer 306: X=219, Y=532
# Pointer 307: X=292, Y=591
# Pointer 308: X=283, Y=598
# Pointer 309: X=288, Y=590
# Pointer 310: X=202, Y=525
# Pointer 311: X=259, Y=593
# Pointer 312: X=242, Y=596
# Pointer 313: X=223, Y=600
# Pointer 314: X=252, Y=651
# Pointer 315: X=238, Y=637
# Pointer 316: X=232, Y=627
# Pointer 317: X=229, Y=618
# Pointer 318: X=227, Y=612
# Pointer 319: X=263, Y=601
# Pointer 320: X=266, Y=602
# Pointer 321: X=270, Y=606
# Pointer 322: X=276, Y=611
# Pointer 323: X=276, Y=560
# Pointer 324: X=473, Y=449
# Pointer 325: X=276, Y=596
# Pointer 326: X=278, Y=597
# Pointer 327: X=205, Y=546
# Pointer 328: X=238, Y=534
# Pointer 329: X=206, Y=542
# Pointer 330: X=258, Y=468
# Pointer 331: X=289, Y=471
# Pointer 332: X=242, Y=512
# Pointer 333: X=299, Y=271
# Pointer 334: X=280, Y=299
# Pointer 335: X=265, Y=329
# Pointer 336: X=294, Y=622
# Pointer 337: X=188, Y=364
# Pointer 338: X=186, Y=324
# Pointer 339: X=189, Y=284
# Pointer 340: X=311, Y=410
# Pointer 341: X=365, Y=414
# Pointer 342: X=235, Y=427
# Pointer 343: X=328, Y=372
# Pointer 344: X=219, Y=457
# Pointer 345: X=211, Y=512
# Pointer 346: X=396, Y=418
# Pointer 347: X=350, Y=431
# Pointer 348: X=322, Y=445
# Pointer 349: X=285, Y=453
# Pointer 350: X=259, Y=453
# Pointer 351: X=238, Y=451
# Pointer 352: X=183, Y=444
# Pointer 353: X=402, Y=456
# Pointer 354: X=344, Y=365
# Pointer 355: X=175, Y=539
# Pointer 356: X=233, Y=481
# Pointer 357: X=450, Y=370
# Pointer 358: X=221, Y=446
# Pointer 359: X=250, Y=512
# Pointer 360: X=324, Y=387
# Pointer 361: X=214, Y=500
# Pointer 362: X=479, Y=494
# Pointer 363: X=235, Y=421
# Pointer 364: X=191, Y=495
# Pointer 365: X=404, Y=605
# Pointer 366: X=424, Y=623
# Pointer 367: X=445, Y=451
# Pointer 368: X=431, Y=573
# Pointer 369: X=394, Y=346
# Pointer 370: X=318, Y=682
# Pointer 371: X=181, Y=543
# Pointer 372: X=254, Y=488
# Pointer 373: X=385, Y=386
# Pointer 374: X=289, Y=410
# Pointer 375: X=274, Y=416
# Pointer 376: X=289, Y=600
# Pointer 377: X=411, Y=492
# Pointer 378: X=294, Y=711
# Pointer 379: X=358, Y=676
# Pointer 380: X=388, Y=654
# Pointer 381: X=260, Y=419
# Pointer 382: X=248, Y=420
# Pointer 383: X=240, Y=421
# Pointer 384: X=364, Y=357
# Pointer 385: X=245, Y=406
# Pointer 386: X=256, Y=397
# Pointer 387: X=270, Y=391
# Pointer 388: X=286, Y=388
# Pointer 389: X=298, Y=388
# Pointer 390: X=424, Y=332
# Pointer 391: X=300, Y=403
# Pointer 392: X=253, Y=555
# Pointer 393: X=218, Y=525
# Pointer 394: X=211, Y=558
# Pointer 395: X=376, Y=635
# Pointer 396: X=349, Y=659
# Pointer 397: X=284, Y=701
# Pointer 398: X=454, Y=588
# Pointer 399: X=237, Y=416
# Pointer 400: X=197, Y=466
# Pointer 401: X=326, Y=695
# Pointer 402: X=452, Y=492
# Pointer 403: X=246, Y=606
# Pointer 404: X=249, Y=610
# Pointer 405: X=253, Y=616
# Pointer 406: X=258, Y=625
# Pointer 407: X=275, Y=638
# Pointer 408: X=277, Y=591
# Pointer 409: X=280, Y=589
# Pointer 410: X=284, Y=585
# Pointer 411: X=298, Y=570
# Pointer 412: X=375, Y=511
# Pointer 413: X=200, Y=449
# Pointer 414: X=213, Y=413
# Pointer 415: X=227, Y=412
# Pointer 416: X=275, Y=590
# Pointer 417: X=400, Y=552
# Pointer 418: X=191, Y=418
# Pointer 419: X=293, Y=651
# Pointer 420: X=179, Y=462
# Pointer 421: X=214, Y=487
# Pointer 422: X=263, Y=667
# Pointer 423: X=330, Y=608
# Pointer 424: X=270, Y=522
# Pointer 425: X=315, Y=632
# Pointer 426: X=314, Y=508
# Pointer 427: X=292, Y=534
# Pointer 428: X=343, Y=532
# Pointer 429: X=274, Y=686
# Pointer 430: X=232, Y=493
# Pointer 431: X=355, Y=618
# Pointer 432: X=333, Y=643
# Pointer 433: X=338, Y=583
# Pointer 434: X=419, Y=524
# Pointer 435: X=371, Y=579
# Pointer 436: X=451, Y=532
# Pointer 437: X=316, Y=553
# Pointer 438: X=215, Y=473
# Pointer 439: X=205, Y=521
# Pointer 440: X=225, Y=522
# Pointer 441: X=189, Y=512
# Pointer 442: X=218, Y=394
# Pointer 443: X=239, Y=374
# Pointer 444: X=262, Y=362
# Pointer 445: X=286, Y=358
# Pointer 446: X=309, Y=360
# Pointer 447: X=340, Y=388
# Pointer 448: X=434, Y=413
# Pointer 449: X=328, Y=418
# Pointer 450: X=308, Y=430
# Pointer 451: X=283, Y=437
# Pointer 452: X=260, Y=440
# Pointer 453: X=242, Y=439
# Pointer 454: X=229, Y=437
# Pointer 455: X=464, Y=409
# Pointer 456: X=229, Y=526
# Pointer 457: X=193, Y=481
# Pointer 458: X=187, Y=525
# Pointer 459: X=185, Y=535
# Pointer 460: X=192, Y=528
# Pointer 461: X=229, Y=533
# Pointer 462: X=181, Y=537
# Pointer 463: X=186, Y=541
# Pointer 464: X=227, Y=423
# Pointer 465: X=216, Y=431
# Pointer 466: X=207, Y=436
# Pointer 467: X=307, Y=389
# Pointer 468: X=316, Y=376

# %%
import tkinter as tk
import cv2
import mediapipe as mp
from PIL import ImageTk, Image

 
# Function to perform landmark detection on the provided image path
def detect_landmarks(image_path):
    
    mp_face_mesh = mp.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh()
    
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    results = face_mesh.process(image_rgb)

    pointer_locations = []
    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            for i, landmark in enumerate(face_landmarks.landmark):
                x = int(landmark.x * image.shape[1])
                y = int(landmark.y * image.shape[0])
                pointer_locations.append((x, y))
                cv2.circle(image, (x, y), radius=2, color=(0, 0, 0), thickness=-1)
                cv2.putText(image, f"({x}, {y})",  (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.15, (0, 0, 0), 1, cv2.LINE_AA)

    return image, pointer_locations

# %%
# Create a Tkinter window
window = tk.Tk()
window.title("Landmark Detection")

# Create a frame with a border
frame = tk.Frame(window, relief=tk.RAISED, borderwidth=2)
frame.pack(padx=10, pady=10)

# Specify the image path here
image_path = 'C:/Users/ASUS/OneDrive/Pictures/Saved Pictures/1.jpg'

# Perform landmark detection on the specified image path
image, landmark_locations = detect_landmarks(image_path)

# Convert the image to PIL format and create an ImageTk object
image_pil = Image.fromarray(image)
image_tk = ImageTk.PhotoImage(image_pil)

# Create a label widget to display the image
image_label = tk.Label(frame, image=image_tk)
image_label.pack()

# Print the pointer locations
for i, (x, y) in enumerate(landmark_locations):
    print(f"Pointer {i+1}: X={x}, Y={y}")

# Run the Tkinter event loop
window.mainloop()
# Out:
# Pointer 1: X=402, Y=469
# Pointer 2: X=402, Y=417
# Pointer 3: X=401, Y=434
# Pointer 4: X=391, Y=367
# Pointer 5: X=402, Y=401
# Pointer 6: X=403, Y=381
# Pointer 7: X=405, Y=335
# Pointer 8: X=300, Y=334
# Pointer 9: X=406, Y=302
# Pointer 10: X=407, Y=282
# Pointer 11: X=409, Y=219
# Pointer 12: X=402, Y=476
# Pointer 13: X=402, Y=482
# Pointer 14: X=401, Y=484
# Pointer 15: X=402, Y=486
# Pointer 16: X=402, Y=492
# Pointer 17: X=402, Y=500
# Pointer 18: X=401, Y=509
# Pointer 19: X=400, Y=526
# Pointer 20: X=401, Y=425
# Pointer 21: X=388, Y=424
# Pointer 22: X=256, Y=284
# Pointer 23: X=343, Y=347
# Pointer 24: X=329, Y=348
# Pointer 25: X=315, Y=348
# Pointer 26: X=296, Y=340
# Pointer 27: X=355, Y=342
# Pointer 28: X=323, Y=310
# Pointer 29: X=338, Y=311
# Pointer 30: X=309, Y=312
# Pointer 31: X=299, Y=317
# Pointer 32: X=287, Y=349
# Pointer 33: X=342, Y=550
# Pointer 34: X=295, Y=331
# Pointer 35: X=250, Y=345
# Pointer 36: X=272, Y=339
# Pointer 37: X=331, Y=405
# Pointer 38: X=383, Y=465
# Pointer 39: X=386, Y=481
# Pointer 40: X=364, Y=470
# Pointer 41: X=353, Y=475
# Pointer 42: X=372, Y=482
# Pointer 43: X=361, Y=483
# Pointer 44: X=334, Y=498
# Pointer 45: X=389, Y=416
# Pointer 46: X=388, Y=401
# Pointer 47: X=278, Y=299
# Pointer 48: X=360, Y=369
# Pointer 49: X=355, Y=412
# Pointer 50: X=355, Y=405
# Pointer 51: X=291, Y=404
# Pointer 52: X=389, Y=383
# Pointer 53: X=311, Y=282
# Pointer 54: X=291, Y=287
# Pointer 55: X=269, Y=258
# Pointer 56: X=375, Y=297
# Pointer 57: X=351, Y=316
# Pointer 58: X=323, Y=484
# Pointer 59: X=260, Y=481
# Pointer 60: X=366, Y=421
# Pointer 61: X=378, Y=426
# Pointer 62: X=339, Y=485
# Pointer 63: X=346, Y=484
# Pointer 64: X=284, Y=278
# Pointer 65: X=355, Y=419
# Pointer 66: X=338, Y=284
# Pointer 67: X=336, Y=272
# Pointer 68: X=326, Y=224
# Pointer 69: X=277, Y=267
# Pointer 70: X=332, Y=247
# Pointer 71: X=271, Y=293
# Pointer 72: X=263, Y=289
# Pointer 73: X=384, Y=475
# Pointer 74: X=369, Y=477
# Pointer 75: X=357, Y=479
# Pointer 76: X=369, Y=424
# Pointer 77: X=343, Y=484
# Pointer 78: X=349, Y=487
# Pointer 79: X=347, Y=483
# Pointer 80: X=374, Y=416
# Pointer 81: X=364, Y=482
# Pointer 82: X=375, Y=482
# Pointer 83: X=387, Y=483
# Pointer 84: X=380, Y=525
# Pointer 85: X=383, Y=507
# Pointer 86: X=384, Y=498
# Pointer 87: X=386, Y=490
# Pointer 88: X=387, Y=485
# Pointer 89: X=363, Y=484
# Pointer 90: X=360, Y=486
# Pointer 91: X=357, Y=490
# Pointer 92: X=354, Y=495
# Pointer 93: X=340, Y=459
# Pointer 94: X=249, Y=411
# Pointer 95: X=401, Y=429
# Pointer 96: X=355, Y=484
# Pointer 97: X=353, Y=485
# Pointer 98: X=383, Y=433
# Pointer 99: X=360, Y=429
# Pointer 100: X=380, Y=430
# Pointer 101: X=346, Y=378
# Pointer 102: X=323, Y=387
# Pointer 103: X=352, Y=411
# Pointer 104: X=291, Y=237
# Pointer 105: X=298, Y=252
# Pointer 106: X=306, Y=271
# Pointer 107: X=345, Y=508
# Pointer 108: X=371, Y=277
# Pointer 109: X=368, Y=248
# Pointer 110: X=364, Y=219
# Pointer 111: X=303, Y=345
# Pointer 112: X=273, Y=359
# Pointer 113: X=362, Y=338
# Pointer 114: X=285, Y=320
# Pointer 115: X=371, Y=359
# Pointer 116: X=364, Y=407
# Pointer 117: X=259, Y=370
# Pointer 118: X=282, Y=369
# Pointer 119: X=299, Y=374
# Pointer 120: X=326, Y=372
# Pointer 121: X=345, Y=366
# Pointer 122: X=360, Y=359
# Pointer 123: X=390, Y=339
# Pointer 124: X=261, Y=400
# Pointer 125: X=274, Y=318
# Pointer 126: X=394, Y=424
# Pointer 127: X=361, Y=383
# Pointer 128: X=247, Y=347
# Pointer 129: X=371, Y=351
# Pointer 130: X=351, Y=413
# Pointer 131: X=291, Y=331
# Pointer 132: X=364, Y=397
# Pointer 133: X=252, Y=445
# Pointer 134: X=361, Y=333
# Pointer 135: X=376, Y=388
# Pointer 136: X=285, Y=514
# Pointer 137: X=286, Y=532
# Pointer 138: X=249, Y=406
# Pointer 139: X=270, Y=494
# Pointer 140: X=257, Y=315
# Pointer 141: X=338, Y=566
# Pointer 142: X=395, Y=428
# Pointer 143: X=348, Y=394
# Pointer 144: X=261, Y=343
# Pointer 145: X=316, Y=339
# Pointer 146: X=329, Y=340
# Pointer 147: X=345, Y=490
# Pointer 148: X=262, Y=429
# Pointer 149: X=364, Y=590
# Pointer 150: X=321, Y=567
# Pointer 151: X=304, Y=552
# Pointer 152: X=408, Y=250
# Pointer 153: X=396, Y=594
# Pointer 154: X=341, Y=339
# Pointer 155: X=351, Y=336
# Pointer 156: X=358, Y=334
# Pointer 157: X=265, Y=316
# Pointer 158: X=349, Y=325
# Pointer 159: X=337, Y=321
# Pointer 160: X=325, Y=320
# Pointer 161: X=312, Y=322
# Pointer 162: X=304, Y=326
# Pointer 163: X=249, Y=312
# Pointer 164: X=307, Y=337
# Pointer 165: X=402, Y=445
# Pointer 166: X=353, Y=450
# Pointer 167: X=365, Y=418
# Pointer 168: X=381, Y=446
# Pointer 169: X=405, Y=319
# Pointer 170: X=301, Y=534
# Pointer 171: X=318, Y=550
# Pointer 172: X=364, Y=578
# Pointer 173: X=272, Y=510
# Pointer 174: X=357, Y=330
# Pointer 175: X=380, Y=362
# Pointer 176: X=397, Y=583
# Pointer 177: X=340, Y=580
# Pointer 178: X=252, Y=437
# Pointer 179: X=374, Y=484
# Pointer 180: X=372, Y=488
# Pointer 181: X=369, Y=494
# Pointer 182: X=367, Y=502
# Pointer 183: X=361, Y=518
# Pointer 184: X=352, Y=484
# Pointer 185: X=348, Y=482
# Pointer 186: X=344, Y=480
# Pointer 187: X=329, Y=470
# Pointer 188: X=279, Y=436
# Pointer 189: X=381, Y=348
# Pointer 190: X=373, Y=323
# Pointer 191: X=364, Y=326
# Pointer 192: X=355, Y=482
# Pointer 193: X=276, Y=472
# Pointer 194: X=386, Y=321
# Pointer 195: X=351, Y=533
# Pointer 196: X=404, Y=365
# Pointer 197: X=390, Y=354
# Pointer 198: X=404, Y=351
# Pointer 199: X=369, Y=385
# Pointer 200: X=398, Y=565
# Pointer 201: X=399, Y=544
# Pointer 202: X=374, Y=542
# Pointer 203: X=319, Y=505
# Pointer 204: X=340, Y=425
# Pointer 205: X=333, Y=521
# Pointer 206: X=309, Y=422
# Pointer 207: X=326, Y=439
# Pointer 208: X=296, Y=446
# Pointer 209: X=367, Y=561
# Pointer 210: X=360, Y=394
# Pointer 211: X=306, Y=517
# Pointer 212: X=324, Y=534
# Pointer 213: X=308, Y=486
# Pointer 214: X=265, Y=454
# Pointer 215: X=291, Y=488
# Pointer 216: X=258, Y=467
# Pointer 217: X=315, Y=459
# Pointer 218: X=371, Y=372
# Pointer 219: X=369, Y=413
# Pointer 220: X=359, Y=417
# Pointer 221: X=375, Y=403
# Pointer 222: X=362, Y=310
# Pointer 223: X=339, Y=301
# Pointer 224: X=319, Y=299
# Pointer 225: X=302, Y=301
# Pointer 226: X=290, Y=308
# Pointer 227: X=283, Y=335
# Pointer 228: X=247, Y=375
# Pointer 229: X=294, Y=355
# Pointer 230: X=308, Y=359
# Pointer 231: X=327, Y=359
# Pointer 232: X=345, Y=355
# Pointer 233: X=358, Y=350
# Pointer 234: X=368, Y=345
# Pointer 235: X=248, Y=379
# Pointer 236: X=360, Y=421
# Pointer 237: X=379, Y=375
# Pointer 238: X=379, Y=414
# Pointer 239: X=387, Y=422
# Pointer 240: X=379, Y=417
# Pointer 241: X=364, Y=426
# Pointer 242: X=390, Y=423
# Pointer 243: X=391, Y=427
# Pointer 244: X=367, Y=334
# Pointer 245: X=375, Y=337
# Pointer 246: X=380, Y=339
# Pointer 247: X=299, Y=328
# Pointer 248: X=292, Y=323
# Pointer 249: X=416, Y=368
# Pointer 250: X=511, Y=343
# Pointer 251: X=415, Y=425
# Pointer 252: X=557, Y=296
# Pointer 253: X=467, Y=351
# Pointer 254: X=481, Y=354
# Pointer 255: X=495, Y=354
# Pointer 256: X=515, Y=348
# Pointer 257: X=456, Y=347
# Pointer 258: X=489, Y=317
# Pointer 259: X=474, Y=317
# Pointer 260: X=503, Y=320
# Pointer 261: X=513, Y=325
# Pointer 262: X=523, Y=358
# Pointer 263: X=454, Y=554
# Pointer 264: X=516, Y=339
# Pointer 265: X=560, Y=357
# Pointer 266: X=538, Y=350
# Pointer 267: X=476, Y=410
# Pointer 268: X=421, Y=466
# Pointer 269: X=418, Y=482
# Pointer 270: X=441, Y=471
# Pointer 271: X=453, Y=478
# Pointer 272: X=432, Y=483
# Pointer 273: X=443, Y=485
# Pointer 274: X=469, Y=502
# Pointer 275: X=414, Y=417
# Pointer 276: X=417, Y=402
# Pointer 277: X=535, Y=310
# Pointer 278: X=448, Y=372
# Pointer 279: X=449, Y=415
# Pointer 280: X=450, Y=408
# Pointer 281: X=516, Y=411
# Pointer 282: X=417, Y=384
# Pointer 283: X=503, Y=291
# Pointer 284: X=522, Y=298
# Pointer 285: X=547, Y=269
# Pointer 286: X=438, Y=300
# Pointer 287: X=461, Y=321
# Pointer 288: X=481, Y=488
# Pointer 289: X=537, Y=492
# Pointer 290: X=438, Y=423
# Pointer 291: X=426, Y=428
# Pointer 292: X=466, Y=488
# Pointer 293: X=459, Y=487
# Pointer 294: X=531, Y=289
# Pointer 295: X=449, Y=422
# Pointer 296: X=476, Y=291
# Pointer 297: X=479, Y=279
# Pointer 298: X=492, Y=230
# Pointer 299: X=539, Y=278
# Pointer 300: X=484, Y=254
# Pointer 301: X=543, Y=304
# Pointer 302: X=550, Y=301
# Pointer 303: X=420, Y=475
# Pointer 304: X=436, Y=478
# Pointer 305: X=448, Y=481
# Pointer 306: X=434, Y=426
# Pointer 307: X=462, Y=487
# Pointer 308: X=456, Y=489
# Pointer 309: X=458, Y=486
# Pointer 310: X=430, Y=417
# Pointer 311: X=441, Y=484
# Pointer 312: X=429, Y=484
# Pointer 313: X=416, Y=484
# Pointer 314: X=420, Y=526
# Pointer 315: X=420, Y=508
# Pointer 316: X=420, Y=499
# Pointer 317: X=419, Y=491
# Pointer 318: X=417, Y=486
# Pointer 319: X=442, Y=486
# Pointer 320: X=445, Y=488
# Pointer 321: X=448, Y=492
# Pointer 322: X=450, Y=498
# Pointer 323: X=465, Y=462
# Pointer 324: X=553, Y=422
# Pointer 325: X=450, Y=487
# Pointer 326: X=452, Y=487
# Pointer 327: X=421, Y=435
# Pointer 328: X=444, Y=431
# Pointer 329: X=423, Y=431
# Pointer 330: X=462, Y=382
# Pointer 331: X=485, Y=393
# Pointer 332: X=452, Y=415
# Pointer 333: X=526, Y=246
# Pointer 334: X=518, Y=262
# Pointer 335: X=509, Y=280
# Pointer 336: X=456, Y=512
# Pointer 337: X=444, Y=281
# Pointer 338: X=449, Y=252
# Pointer 339: X=454, Y=223
# Pointer 340: X=508, Y=353
# Pointer 341: X=536, Y=369
# Pointer 342: X=449, Y=342
# Pointer 343: X=527, Y=330
# Pointer 344: X=438, Y=362
# Pointer 345: X=440, Y=409
# Pointer 346: X=549, Y=380
# Pointer 347: X=527, Y=378
# Pointer 348: X=509, Y=381
# Pointer 349: X=483, Y=377
# Pointer 350: X=463, Y=370
# Pointer 351: X=449, Y=362
# Pointer 352: X=419, Y=340
# Pointer 353: X=545, Y=410
# Pointer 354: X=538, Y=329
# Pointer 355: X=409, Y=425
# Pointer 356: X=446, Y=386
# Pointer 357: X=561, Y=359
# Pointer 358: X=438, Y=353
# Pointer 359: X=453, Y=416
# Pointer 360: X=520, Y=341
# Pointer 361: X=441, Y=400
# Pointer 362: X=548, Y=457
# Pointer 363: X=450, Y=337
# Pointer 364: X=429, Y=390
# Pointer 365: X=514, Y=523
# Pointer 366: X=510, Y=541
# Pointer 367: X=555, Y=417
# Pointer 368: X=529, Y=503
# Pointer 369: X=555, Y=327
# Pointer 370: X=456, Y=571
# Pointer 371: X=407, Y=428
# Pointer 372: X=458, Y=398
# Pointer 373: X=549, Y=354
# Pointer 374: X=495, Y=346
# Pointer 375: X=482, Y=346
# Pointer 376: X=459, Y=493
# Pointer 377: X=542, Y=439
# Pointer 378: X=428, Y=593
# Pointer 379: X=472, Y=574
# Pointer 380: X=490, Y=560
# Pointer 381: X=470, Y=344
# Pointer 382: X=460, Y=340
# Pointer 383: X=453, Y=339
# Pointer 384: X=546, Y=327
# Pointer 385: X=463, Y=330
# Pointer 386: X=475, Y=328
# Pointer 387: X=487, Y=327
# Pointer 388: X=500, Y=330
# Pointer 389: X=508, Y=334
# Pointer 390: X=561, Y=324
# Pointer 391: X=504, Y=345
# Pointer 392: X=451, Y=453
# Pointer 393: X=438, Y=421
# Pointer 394: X=423, Y=447
# Pointer 395: X=496, Y=542
# Pointer 396: X=477, Y=557
# Pointer 397: X=430, Y=581
# Pointer 398: X=524, Y=519
# Pointer 399: X=454, Y=334
# Pointer 400: X=428, Y=364
# Pointer 401: X=452, Y=585
# Pointer 402: X=550, Y=448
# Pointer 403: X=431, Y=486
# Pointer 404: X=433, Y=489
# Pointer 405: X=435, Y=496
# Pointer 406: X=437, Y=504
# Pointer 407: X=440, Y=520
# Pointer 408: X=453, Y=486
# Pointer 409: X=457, Y=485
# Pointer 410: X=461, Y=483
# Pointer 411: X=476, Y=474
# Pointer 412: X=525, Y=444
# Pointer 413: X=429, Y=350
# Pointer 414: X=438, Y=326
# Pointer 415: X=447, Y=329
# Pointer 416: X=450, Y=484
# Pointer 417: X=526, Y=481
# Pointer 418: X=425, Y=323
# Pointer 419: X=447, Y=537
# Pointer 420: X=418, Y=355
# Pointer 421: X=437, Y=387
# Pointer 422: X=424, Y=544
# Pointer 423: X=482, Y=510
# Pointer 424: X=465, Y=429
# Pointer 425: X=466, Y=526
# Pointer 426: X=498, Y=429
# Pointer 427: X=479, Y=445
# Pointer 428: X=509, Y=454
# Pointer 429: X=428, Y=564
# Pointer 430: X=446, Y=397
# Pointer 431: X=493, Y=524
# Pointer 432: X=474, Y=540
# Pointer 433: X=494, Y=492
# Pointer 434: X=537, Y=464
# Pointer 435: X=510, Y=496
# Pointer 436: X=542, Y=477
# Pointer 437: X=490, Y=464
# Pointer 438: X=437, Y=375
# Pointer 439: X=435, Y=415
# Pointer 440: X=445, Y=420
# Pointer 441: X=429, Y=405
# Pointer 442: X=450, Y=314
# Pointer 443: X=474, Y=307
# Pointer 444: X=494, Y=307
# Pointer 445: X=511, Y=310
# Pointer 446: X=522, Y=318
# Pointer 447: X=528, Y=345
# Pointer 448: X=559, Y=387
# Pointer 449: X=516, Y=363
# Pointer 450: X=501, Y=366
# Pointer 451: X=483, Y=365
# Pointer 452: X=465, Y=360
# Pointer 453: X=451, Y=354
# Pointer 454: X=442, Y=348
# Pointer 455: X=557, Y=391
# Pointer 456: X=444, Y=424
# Pointer 457: X=428, Y=376
# Pointer 458: X=425, Y=415
# Pointer 459: X=416, Y=423
# Pointer 460: X=424, Y=418
# Pointer 461: X=440, Y=428
# Pointer 462: X=413, Y=424
# Pointer 463: X=412, Y=428
# Pointer 464: X=445, Y=337
# Pointer 465: X=435, Y=340
# Pointer 466: X=430, Y=341
# Pointer 467: X=513, Y=337
# Pointer 468: X=520, Y=332
